# %%
import pandas as pd

df = pd.read_csv("tracks_top_100.csv")

# %%
df = df.drop_duplicates()
print(len(df))
# Out:
# 85033

# %%
new = df.drop("release_id", axis=1)
new = new.drop_duplicates()
print(len(new))
# Out:
# 57895

# %%
new = new.drop("release_date", axis=1)
new = new.drop_duplicates()
print(len(new))
new
# Out:
# 42574
#          artist_name                           artist_mbid  \
# 0         The Weeknd  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 1         The Weeknd  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 2         The Weeknd  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 3         The Weeknd  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 4         The Weeknd  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# ...              ...                                   ...
# 85134  Billie Eilish  f4abc0b5-3f7a-4eff-8f78-ac078dbce533
# 85149  Billie Eilish  f4abc0b5-3f7a-4eff-8f78-ac078dbce533
# 85150  Billie Eilish  f4abc0b5-3f7a-4eff-8f78-ac078dbce533
# 85151  Billie Eilish  f4abc0b5-3f7a-4eff-8f78-ac078dbce533
# 85185  Billie Eilish  f4abc0b5-3f7a-4eff-8f78-ac078dbce533
#
#                                   release_title  \
# 0                                            XO
# 1                                            XO
# 2                                            XO
# 3                                            XO
# ...

# %%
new["recording_id"].nunique()
# Out:
# 24148
