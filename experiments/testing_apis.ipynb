# %%
import os

# %%
os.chdir('../')

# %%
import apis.musicbrainz as mb

# %%
test_mbid = 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9'

# %%
mb.lookup_artist(test_mbid)
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 mb.lookup_artist(test_mbid)
#
# File ~/git/nepo-music/apis/musicbrainz.py:306, in lookup_artist(mbid, includes)
#     296 """
#     297 Look up a single artist by MBID from the local MusicBrainz PostgreSQL DB.
#     298
#    (...)    303     'url-rels' -> returns URL relations in 'relations'
#     304 """
#     305 includes = set(includes or [])
# --> 306 row = _get_artist_row_by_gid(mbid)
#     307 if not row:
#     308     raise MBError(f"No artist found for MBID {mbid}")
#
# File ~/git/nepo-music/apis/musicbrainz.py:189, in _get_artist_row_by_gid(artist_gid)
#     167 """
#     168 Fetch the artist core row (including internal integer id) by MBID (gid).
#     169 """
#     170 sql = """
#     171     SELECT
#     172         a.id                AS artist_int_id,
#    (...)    187     LIMIT 1
#     188 """
# --> 189 return _fetchone(sql, (artist_gid,))
#
# File ~/git/nepo-music/apis/musicbrainz.py:151, in _fetchone(sql, params)
#     149 conn = _get_conn()
#     150 with conn.cursor() as cur:
# --> 151     cur.execute(sql, params)
#     152     return cur.fetchone()
#
# File ~/git/nepo-music/.venv/lib/python3.14/site-packages/psycopg/cursor.py:97, in Cursor.execute(self, query, params, prepare, binary)
#      93         self._conn.wait(
#      94             self._execute_gen(query, params, prepare=prepare, binary=binary)
#      95         )
#      96 except e._NO_TRACEBACK as ex:
# ---> 97     raise ex.with_traceback(None)
#      98 return self
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block

# %%
from importlib import reload
reload(mb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 from importlib import reload
# ----> 2 reload(mb)
#
# NameError: name 'mb' is not defined

# %%
works = mb.get_artist_works(test_mbid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 works = mb.get_artist_works(test_mbid)
#
# NameError: name 'mb' is not defined

# %%
len(works)
# Out:
# 198

# %%
works[1]
# Out:
# {'iswcs': ['T-929.744.911-7'],
#  'id': '04ccb6fa-84ed-49fe-94ae-15050bb86b91',
#  'title': 'Blinding Lights',
#  'language': 'eng',
#  'disambiguation': '',
#  'attributes': [{'type': 'AACIMH ID',
#    'type-id': 'a9551cb7-ee2c-4b05-87b6-18ef0e549865',
#    'value': '5127668'},
#   {'type-id': '955305a2-58ec-4c64-94f7-7fb9b209416c',
#    'value': '5127668',
#    'type': 'ACAM ID'},
#   {'type-id': 'd12e548d-4579-4ddd-abb6-9ffa4fee6826',
#    'value': '5127668',
#    'type': 'AEI ID'},
#   {'type': 'AGADU ID',
#    'type-id': '27ea7f59-9f9c-4aee-b31a-61109ac03819',
#    'value': '6468859'},
#   {'value': 'GW56281296',
#    'type-id': 'bdf50af8-0881-322a-8ab7-f031a4935d04',
#    'type': 'APRA ID'},
#   {'type': 'ASCAP ID',
#    'value': '898115729',
#    'type-id': 'd833318c-6c6a-370e-8b16-9cb15873ba76'},
#   {'type-id': 'a6492434-b847-4f1b-9869-9184ade990ed',
#    'value': 'W-019658898',
#    'type': 'BUMA/STEMRA ID'},
#   {'type': 'COMPASS ID',
#    'type-id': '5ea37343-be89-4cd0-8a37-f471738df641',
#    'value': '18326258'},
#   {'type-id': 'd37a8c27-8f83-47c7-954d-175d35759990',
#    'value': '23408047',
#    'type': 'ECAD ID'},
#   {'type': 'GEMA ID',
#    'type-id': '01eeee67-f514-3801-bdce-279e04872f91',
#    'value': '24420124-001'},
#   {'type-id': '31048fcc-3dbb-3979-8f85-805afb933e0c',
#    'value': '7F0-5228-1',
#    'type': 'JASRAC ID'},
#   {'type': 'LatinNet ID',
#    'value': '6267',
#    'type-id': '78cf692f-a43b-46fc-993b-635c5bd86375'},
#   {'type-id': '5ab3cd1a-b9ad-4244-8b32-b3a958d4ede6',
#    'value': '5127668',
#    'type': 'NICAUTOR ID'},
#   {'type': 'PRS tune code',
#    'value': '383587KM',
#    'type-id': 'cd76035f-b94e-4e47-850d-aa2cd825d1a6'},
#   {'value': 'A0DIM9A00',
#    'type-id': 'b2e4067b-a9e4-44fb-bfcd-3c1fc41dc06d',
#    'type': 'SABAM ID'},
#   {'value': '41 984 398 11',
#    'type-id': 'd08147e2-d167-3c2b-bbe4-af6643a194f9',
#    'type': 'SACEM ID'},
#   {'type': 'SACIM ID',
#    'value': '5127668',
#    'type-id': '43b74305-291f-4ae3-9e59-0dca457c00fe'},
#   {'type-id': 'd8aa6512-314a-478d-bd30-e8d7411509cb',
#    'value': '2115115',
#    'type': 'SADAIC ID'},
#   {'type': 'SAYCE ID',
#    'type-id': '4bcbb212-a973-46ee-8160-e9f0f89ca6ef',
#    'value': '11880820'},
#   {'value': '5127668',
#    'type-id': '33fe1f90-d812-48ef-839f-bc151afecaca',
#    'type': 'SGACEDOM ID'},
#   {'type-id': '6a200b13-ca08-3b32-87a9-7aaa46368d75',
#    'value': '18.646.996',
#    'type': 'SGAE ID'},
#   {'type-id': '2e4f9e12-d094-4bd0-b4dd-a560cc5c4977',
#    'value': '19811564700',
#    'type': 'SIAE ID'},
#   {'value': '5127668',
#    'type-id': '3667d8d9-9fe4-4df0-873b-4dc00a886d80',
#    'type': 'SOBODAYCOM ID'},
#   {'type-id': '00370bc6-7388-34a1-aa5b-b0e081ccb53d',
#    'value': '205244661',
#    'type': 'SOCAN ID'},
#   {'type': 'SPA ID',
#    'type-id': 'f15e9a05-231e-415b-8b7d-8ec44c736bde',
#    'value': '7037169'},
#   {'value': '5127668',
#    'type-id': 'fd46ccc3-b3bb-4c5a-b40d-23b81899ef46',
#    'type': 'SPAC ID'},
#   {'value': '46993357',
#    'type-id': 'f13230c8-0ddb-4012-8b85-63b6c73b4858',
#    'type': 'STIM ID'},
#   {'type-id': '034f35ae-d250-3749-95e7-854e606d5960',
#    'value': '006383 837 15',
#    'type': 'SUISA ID'}],
#  'type': 'Song',
#  'languages': ['eng'],
#  'type-id': 'f061270a-2fd6-32f1-a641-f0f8676d14e6'}
