# %%
import os

# %%
os.chdir('../')

# %%
import apis.musicbrainz as mb

# %%
test_mbid = 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9'

# %%
from importlib import reload
reload(mb)
# Out:
# <module 'apis.musicbrainz' from '/home/woodbkb2/git/nepo-music/apis/musicbrainz.py'>

# %%
mbid_info = list(mb.stream_artists_songs_by_mbids([test_mbid]))

# %%
mbid_info
# Out:
# [{'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#   'artist_name': 'The Weeknd',
#   'roles': 'arranger, composer, instrument, lyricist, performer, producer, programming, remixer, vocal, writer',
#   'country': 'Canada',
#   'region_city': 'Scarborough',
#   'works': [{'id': 420723,
#     'name': 'Take On Me',
#     'first_release_date': '1984-01-01',
#     'genres': ['pop'],
#     'collaborators': [{'mbid': '1ac73985-2cfa-433a-a6f8-379480e87179',
#       'name': 'Magne Furuholmen',
#       'roles': ['writer']},
#      {'mbid': '2093207d-cb69-4789-866b-5ac772c9ebd3',
#       'name': 'Morten Harket',
#       'roles': ['writer']},
#      {'mbid': '0ef9b4c4-4a41-4ad8-9c64-98c0419c0150',
#       'name': 'Paul Waaktaar-Savoy',
#       'roles': ['writer']}]},
#    {'id': 441573,
#     'name': 'Dirty Diana',
#     'first_release_date': '1987-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'f27ec8db-af05-4f36-916e-3d57f91ecf5e',
#       'name': 'Michael Jackson',
#       'roles': ['composer', 'lyricist']}]},
#    {'id': 12631624,
#     'name': 'High for This',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '22ba7da7-40c1-4bbc-a833-3242295135d2',
#       'name': 'Adrien Gough',
#       'roles': ['writer']},
#      {'mbid': '0eb93ee5-2e6a-4ab4-a988-99c9139a664a',
#       'name': 'Cirkut',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12740571,
#     'name': 'Money Power Glory',
#     'first_release_date': '2014-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'ef2a8c11-a35a-4c61-b750-5cb29c1223f4',
#       'name': 'Greg Kurstin',
#       'roles': ['writer']},
#      {'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6',
#       'name': 'Lana Del Rey',
#       'roles': ['writer']}]},
#    {'id': 12792520,
#     'name': 'Earned It (Fifty Shades of Grey)',
#     'first_release_date': '2014-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['composer', 'lyricist', 'writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['composer', 'lyricist', 'writer']},
#      {'mbid': 'dd03ca01-e54a-4960-b1d0-5e7d7f0181e4',
#       'name': 'Stephan Moccio',
#       'roles': ['composer', 'lyricist', 'writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['composer', 'lyricist', 'writer']}]},
#    {'id': 12834420,
#     'name': 'Elastic Heart',
#     'first_release_date': '2013-02-13',
#     'genres': [],
#     'collaborators': [{'mbid': 'da7ac640-6768-4395-9afd-de30282c5921',
#       'name': 'Andrew Swanson',
#       'roles': ['writer']},
#      {'mbid': '2f548675-008d-4332-876c-108b0c7ab9c5',
#       'name': 'Sia',
#       'roles': ['writer']},
#      {'mbid': 'a254127c-575d-4df1-a883-12b5a0748b16',
#       'name': 'Thomas Wesley',
#       'roles': ['writer']}]},
#    {'id': 12834428,
#     'name': 'Elastic Heart',
#     'first_release_date': '2013-10-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'da7ac640-6768-4395-9afd-de30282c5921',
#       'name': 'Andrew Swanson',
#       'roles': ['writer']},
#      {'mbid': '2f548675-008d-4332-876c-108b0c7ab9c5',
#       'name': 'Sia',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']},
#      {'mbid': 'a254127c-575d-4df1-a883-12b5a0748b16',
#       'name': 'Thomas Wesley',
#       'roles': ['writer']}]},
#    {'id': 12851686,
#     'name': 'Love Me Harder',
#     'first_release_date': '2013-02-13',
#     'genres': [],
#     'collaborators': [{'mbid': '0edfb670-e666-41a6-b4e3-141d32944c9e',
#       'name': 'Ali Payami',
#       'roles': ['writer']},
#      {'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '6622a50e-5206-44d0-9ad5-96047a726dcf',
#       'name': 'Max Martin',
#       'roles': ['writer']},
#      {'mbid': '160e6d77-4ad2-46c0-8bef-a456216c6354',
#       'name': 'Peter Svensson',
#       'roles': ['writer']},
#      {'mbid': 'c8af4490-e48a-4f91-aef9-2b1e39369576',
#       'name': 'Savan Kotecha',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12852546,
#     'name': 'Can’t Feel My Face',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '0edfb670-e666-41a6-b4e3-141d32944c9e',
#       'name': 'Ali Payami',
#       'roles': ['writer']},
#      {'mbid': '6622a50e-5206-44d0-9ad5-96047a726dcf',
#       'name': 'Max Martin',
#       'roles': ['writer']},
#      {'mbid': '160e6d77-4ad2-46c0-8bef-a456216c6354',
#       'name': 'Peter Svensson',
#       'roles': ['writer']},
#      {'mbid': 'c8af4490-e48a-4f91-aef9-2b1e39369576',
#       'name': 'Savan Kotecha',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12885860,
#     'name': 'The Hills',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'b8df4f20-fddd-40ea-966e-55028f6043c7',
#       'name': 'Mano',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12895045,
#     'name': 'Nocturnal',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '2d973513-8faa-48c0-b30d-6bd59d6918ca',
#       'name': 'Guy Lawrence',
#       'roles': ['writer']},
#      {'mbid': '7679f4a7-6fa7-4980-9d0d-bb906efd0418',
#       'name': 'Howard Lawrence',
#       'roles': ['writer']},
#      {'mbid': 'b4b4c19f-021f-4d3c-b11a-911d4c95cd1b',
#       'name': 'Jimmy Napes',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12905605,
#     'name': 'Real Life',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': 'dd03ca01-e54a-4960-b1d0-5e7d7f0181e4',
#       'name': 'Stephan Moccio',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12905606,
#     'name': 'Losers',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'dc99e6fd-c710-4f79-b74b-127b4d0b7849',
#       'name': 'Labrinth',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12905648,
#     'name': 'Tell Your Friends',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '045442df-ab42-4538-ba27-01178014d4ea',
#       'name': 'Carl Marshall',
#       'roles': ['writer']},
#      {'mbid': '0d9acc26-03eb-43fc-a12f-b3e106c89d4c',
#       'name': 'Ché Pope',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': '73e36439-1e9a-4925-bf2c-1d7f7885fbb0',
#       'name': 'Mike Dean',
#       'roles': ['writer']},
#      {'mbid': '2dad5809-0d9b-40cf-85cf-2f8828ffaaf0',
#       'name': 'Noah Goldstein',
#       'roles': ['writer']},
#      {'mbid': '2cdcdb76-dfa6-4b10-856f-e6f2f5cbb282',
#       'name': 'Robert Holmes',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']},
#      {'mbid': '164f0d73-1234-4e2c-8743-d77bf2191051',
#       'name': 'Ye',
#       'roles': ['writer']}]},
#    {'id': 12905682,
#     'name': 'Acquainted',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '64675ea9-686f-4de0-b001-aa425dba856a',
#       'name': 'Ben Billions',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12905719,
#     'name': 'Shameless',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '0edfb670-e666-41a6-b4e3-141d32944c9e',
#       'name': 'Ali Payami',
#       'roles': ['writer']},
#      {'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '160e6d77-4ad2-46c0-8bef-a456216c6354',
#       'name': 'Peter Svensson',
#       'roles': ['writer']},
#      {'mbid': 'c8af4490-e48a-4f91-aef9-2b1e39369576',
#       'name': 'Savan Kotecha',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12905722,
#     'name': 'In the Night',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '0edfb670-e666-41a6-b4e3-141d32944c9e',
#       'name': 'Ali Payami',
#       'roles': ['writer']},
#      {'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '6622a50e-5206-44d0-9ad5-96047a726dcf',
#       'name': 'Max Martin',
#       'roles': ['writer']},
#      {'mbid': '160e6d77-4ad2-46c0-8bef-a456216c6354',
#       'name': 'Peter Svensson',
#       'roles': ['writer']},
#      {'mbid': 'c8af4490-e48a-4f91-aef9-2b1e39369576',
#       'name': 'Savan Kotecha',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12905723,
#     'name': 'Dark Times',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': 'b8a7c51f-362c-4dcb-a259-bc6e0095f0a6',
#       'name': 'Ed Sheeran',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 12905726,
#     'name': 'Prisoner',
#     'first_release_date': '1997-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6',
#       'name': 'Lana Del Rey',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13013642,
#     'name': 'Starboy',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '0eb93ee5-2e6a-4ab4-a988-99c9139a664a',
#       'name': 'Cirkut',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '83886397-adf2-431a-b841-dc4af744a6cc',
#       'name': 'Guy‐Manuel de Homem‐Christo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']},
#      {'mbid': '122a2714-24f8-4046-a532-64064b5076d2',
#       'name': 'Thomas Bangalter',
#       'roles': ['writer']}]},
#    {'id': 13014277,
#     'name': 'Professional',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': '3b7834f2-3955-486d-91c9-f95d9166db73',
#       'name': 'Ema Jolly',
#       'roles': ['writer']},
#      {'mbid': '5fea7ef6-52de-4050-a539-825ba94a894d',
#       'name': 'Fin Greenall',
#       'roles': ['writer']},
#      {'mbid': '6c7bea28-c146-4c1d-bda3-bbbb0e18e76b',
#       'name': 'Harry Fraud',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014278,
#     'name': 'The Town',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014279,
#     'name': 'Adaptation',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': '7944ed53-2a58-4035-9b93-140a71e41c34',
#       'name': 'Sting',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014280,
#     'name': 'Love in the Sky',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': '71128735-0907-41a8-ac12-6009c6ac7d1a',
#       'name': 'Richard Munoz',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014281,
#     'name': 'Belong to the World',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '5adcb9d9-5ea2-428d-af46-ef626966e106',
#       'name': 'Beth Gibbons',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': '5082a11f-7203-4ff3-ae04-2a0150d3bbb6',
#       'name': 'Geoff Barrow',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014282,
#     'name': 'Live For',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': '9fff2f8a-21e6-47de-a2b8-7f449929d43f',
#       'name': 'Drake',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014283,
#     'name': 'Wanderlust',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'a7b171ee-f4fd-4fcc-9eee-7f0e113fc707',
#       'name': 'Albert Tamaela',
#       'roles': ['writer']},
#      {'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': '53f68304-e269-49f8-89d0-ce31e07e6900',
#       'name': 'Joseph Bostani',
#       'roles': ['writer']},
#      {'mbid': '71128735-0907-41a8-ac12-6009c6ac7d1a',
#       'name': 'Richard Munoz',
#       'roles': ['writer']},
#      {'mbid': 'a17ebbb6-f9b4-4130-99e0-fb8b43dda499',
#       'name': 'Selfia Musmin',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014284,
#     'name': 'Kiss Land',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': '7441c7c4-5fac-4aac-9fd6-adc9988ff68b',
#       'name': 'Jack Holkeboer',
#       'roles': ['writer']},
#      {'mbid': 'ac69016f-42cc-4322-b70e-101458b769aa',
#       'name': 'Sébastien Tellier',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014285,
#     'name': 'Pretty',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '23b0c0ae-fc61-4ae2-b842-893afc796c36',
#       'name': 'Brandon "Bizzy" Hollemon',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': 'a14fd44e-20a4-4b18-aa9f-0980643c56d7',
#       'name': 'Ricky Hilfiger',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014286,
#     'name': 'Tears in the Rain',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014323,
#     'name': 'Often',
#     'first_release_date': '2014-07-31',
#     'genres': [],
#     'collaborators': [{'mbid': 'c53a0a2e-ca8b-41f0-9308-c886b63449d6',
#       'name': 'Ali Kocatepe',
#       'roles': ['writer']},
#      {'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '64675ea9-686f-4de0-b001-aa425dba856a',
#       'name': 'Ben Billions',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': '613e2ab8-f471-4ece-b18b-5c863608ce77',
#       'name': 'Osman İşmen',
#       'roles': ['writer']},
#      {'mbid': '66fef5a9-5ceb-4427-9670-017fe1c49786',
#       'name': 'Sabahattin Ali',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014324,
#     'name': 'Angel',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '64675ea9-686f-4de0-b001-aa425dba856a',
#       'name': 'Ben Billions',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': 'dd03ca01-e54a-4960-b1d0-5e7d7f0181e4',
#       'name': 'Stephan Moccio',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014329,
#     'name': 'As You Are',
#     'first_release_date': '2015-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014573,
#     'name': 'What You Need',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '33874ca1-1dba-427c-9c0f-93b38117e3a7',
#       'name': 'Jeremy Rose',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014574,
#     'name': 'House of Balloons / Glass Table Girls',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'e5e714af-bf47-4569-868d-f7530e93fa9c',
#       'name': 'Budgie',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'ccc29f42-1b55-40c0-8984-a2fdb8446580',
#       'name': 'John Martin',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': '4de9aada-a5fa-4899-8914-cfcf8dd19066',
#       'name': 'Siouxsie Sioux',
#       'roles': ['writer']},
#      {'mbid': 'c6d3b8aa-40c3-4f6a-9f2d-f10eb4434436',
#       'name': 'Steven Severin',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014575,
#     'name': 'The Morning',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014576,
#     'name': 'Wicked Games',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': '7c7c3a7c-6980-4344-9594-07d6500ee4a2',
#       'name': 'Rainer Millar Blanchaer',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014577,
#     'name': 'The Party & the After Party',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '2bc0d70f-d569-4158-ace7-001566b16d9f',
#       'name': 'Alex Scally',
#       'roles': ['writer']},
#      {'mbid': '33874ca1-1dba-427c-9c0f-93b38117e3a7',
#       'name': 'Jeremy Rose',
#       'roles': ['writer']},
#      {'mbid': '7c7c3a7c-6980-4344-9594-07d6500ee4a2',
#       'name': 'Rainer Millar Blanchaer',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']},
#      {'mbid': 'a06e38d2-2510-4729-b731-56e83fb9dfcc',
#       'name': 'Victoria Legrand',
#       'roles': ['writer']}]},
#    {'id': 13014578,
#     'name': 'Coming Down',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014579,
#     'name': 'Loft Music',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '2bc0d70f-d569-4158-ace7-001566b16d9f',
#       'name': 'Alex Scally',
#       'roles': ['writer']},
#      {'mbid': '33874ca1-1dba-427c-9c0f-93b38117e3a7',
#       'name': 'Jeremy Rose',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']},
#      {'mbid': 'a06e38d2-2510-4729-b731-56e83fb9dfcc',
#       'name': 'Victoria Legrand',
#       'roles': ['writer']}]},
#    {'id': 13014580,
#     'name': 'The Knowing',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '0bf0cabe-def2-4113-8dc5-6e721b9c3a92',
#       'name': 'Elizabeth Fraser',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': '47d7b25e-585b-4c97-b98b-411b21a53379',
#       'name': 'Robin Guthrie',
#       'roles': ['writer']},
#      {'mbid': '54cf21b1-9a02-4a75-a029-3a66db21c545',
#       'name': 'Simon Raymonde',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014581,
#     'name': 'Twenty Eight',
#     'first_release_date': '2012-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014582,
#     'name': 'Lonely Star',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014583,
#     'name': 'Life of the Party',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'a94066bc-245a-4ef2-a714-520a8eb90535',
#       'name': 'Andy Grier',
#       'roles': ['writer']},
#      {'mbid': '9ab1b114-c2d7-4e66-ac91-151bda54a376',
#       'name': 'Björn Berglund',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'ac14b2a8-9d6c-4fc3-8f73-5c2aed399d48',
#       'name': 'Pontus Berghe',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']},
#      {'mbid': 'f31be082-1b7c-4d75-aaea-2b4bddfbaa0f',
#       'name': 'Vincent Reilly',
#       'roles': ['writer']}]},
#    {'id': 13014584,
#     'name': 'Thursday',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014585,
#     'name': 'The Zone',
#     'first_release_date': '2009-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '9fff2f8a-21e6-47de-a2b8-7f449929d43f',
#       'name': 'Drake',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014586,
#     'name': 'The Birds, Part 1',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014587,
#     'name': 'The Birds, Part 2',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'b26e906b-af9c-4061-88d2-d92a2eb868fe',
#       'name': 'Alex McGowan',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'ed785ff1-8b1b-4bc0-8a24-dcc831013059',
#       'name': 'Martina Topley‐Bird',
#       'roles': ['writer']},
#      {'mbid': 'd884aee7-9615-4b8d-bd47-57e2e9f15b10',
#       'name': 'Nick Bird',
#       'roles': ['writer']},
#      {'mbid': 'dffe466e-678b-4edc-be2c-fcc89a8f673a',
#       'name': 'Steve Crittall',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014588,
#     'name': 'Gone',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014589,
#     'name': 'Rolling Stone',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014590,
#     'name': 'Heaven or Las Vegas',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014591,
#     'name': 'Valerie',
#     'first_release_date': '2012-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014592,
#     'name': 'Montreal',
#     'first_release_date': '2011-12-21',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['composer', 'writer']},
#      {'mbid': 'b21ef19b-c6aa-4775-90d3-3cc3e067ce6d',
#       'name': 'Serge Gainsbourg',
#       'roles': ['composer', 'writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014593,
#     'name': 'Outside',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': '6100fb19-ce8d-4ad4-873a-0d16d7024c66',
#       'name': 'Madeline Follin',
#       'roles': ['writer']},
#      {'mbid': '887fcb29-8539-4046-8808-b4987eefd919',
#       'name': 'Ryan Mattos',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014594,
#     'name': 'XO / The Host',
#     'first_release_date': '2011-12-21',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014595,
#     'name': 'Initiation',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'caf1cb4b-5bd0-4b4c-aecf-53de52cd18d1',
#       'name': 'Georgia Anne Muldrow',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': '194d7534-1b67-4c96-a722-b9e44f331b5c',
#       'name': 'Martin Wong',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014596,
#     'name': 'Same Old Song',
#     'first_release_date': '2011-12-21',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'c45d161f-83ce-4464-ba41-44202e6916d9',
#       'name': 'Juicy J',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014597,
#     'name': 'The Fall',
#     'first_release_date': '2011-12-21',
#     'genres': [],
#     'collaborators': [{'mbid': '772a0eb3-fe31-4a08-b583-690296f44900',
#       'name': 'Clams Casino',
#       'roles': ['writer']},
#      {'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014598,
#     'name': 'Next',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': '194d7534-1b67-4c96-a722-b9e44f331b5c',
#       'name': 'Martin Wong',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014599,
#     'name': 'Echoes of Silence',
#     'first_release_date': '2011-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13014600,
#     'name': 'Till Dawn (Here Comes the Sun)',
#     'first_release_date': '2012-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'faf9c4c1-fa6c-45a7-bd51-e91d8eed5577',
#       'name': 'Illangelo',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13016087,
#     'name': 'False Alarm',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '64675ea9-686f-4de0-b001-aa425dba856a',
#       'name': 'Ben Billions',
#       'roles': ['writer']},
#      {'mbid': '0eb93ee5-2e6a-4ab4-a988-99c9139a664a',
#       'name': 'Cirkut',
#       'roles': ['writer']},
#      {'mbid': 'b8df4f20-fddd-40ea-966e-55028f6043c7',
#       'name': 'Mano',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13045606,
#     'name': 'Smokin’ Rollin’',
#     'first_release_date': '2013-08-23',
#     'genres': [],
#     'collaborators': [{'mbid': '22ba7da7-40c1-4bbc-a833-3242295135d2',
#       'name': 'Adrien Gough',
#       'roles': ['writer']},
#      {'mbid': 'e508be7e-c1d2-47e2-a851-3cdc30dfe505',
#       'name': 'Chad Butler',
#       'roles': ['writer']},
#      {'mbid': '0eb93ee5-2e6a-4ab4-a988-99c9139a664a',
#       'name': 'Cirkut',
#       'roles': ['writer']},
#      {'mbid': 'c45d161f-83ce-4464-ba41-44202e6916d9',
#       'name': 'Juicy J',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']},
#      {'mbid': 'f5dfa020-ad69-41cd-b3d4-fd7af0414e94',
#       'name': 'Wiz Khalifa',
#       'roles': ['writer']}]},
#    {'id': 13045622,
#     'name': 'One of Those Nights',
#     'first_release_date': '2013-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '95349431-cc3c-411a-ba15-86b601b3966d',
#       'name': 'Danny "styles" Schofield',
#       'roles': ['writer']},
#      {'mbid': 'c45d161f-83ce-4464-ba41-44202e6916d9',
#       'name': 'Juicy J',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13059909,
#     'name': 'Party Monster',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '64675ea9-686f-4de0-b001-aa425dba856a',
#       'name': 'Ben Billions',
#       'roles': ['writer']},
#      {'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6',
#       'name': 'Lana Del Rey',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13059910,
#     'name': 'Reminder',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '0eb93ee5-2e6a-4ab4-a988-99c9139a664a',
#       'name': 'Cirkut',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': 'b8df4f20-fddd-40ea-966e-55028f6043c7',
#       'name': 'Mano',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'adaf0068-1c86-4166-8cee-f0a53f4854c4',
#       'name': 'Sir Dylan',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13059911,
#     'name': 'Rockin’',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '0edfb670-e666-41a6-b4e3-141d32944c9e',
#       'name': 'Ali Payami',
#       'roles': ['writer']},
#      {'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '6622a50e-5206-44d0-9ad5-96047a726dcf',
#       'name': 'Max Martin',
#       'roles': ['writer']},
#      {'mbid': '160e6d77-4ad2-46c0-8bef-a456216c6354',
#       'name': 'Peter Svensson',
#       'roles': ['writer']},
#      {'mbid': 'c8af4490-e48a-4f91-aef9-2b1e39369576',
#       'name': 'Savan Kotecha',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13059912,
#     'name': 'Secrets',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '0eb93ee5-2e6a-4ab4-a988-99c9139a664a',
#       'name': 'Cirkut',
#       'roles': ['writer']},
#      {'mbid': '4d02809c-f2bd-4cbd-9b36-106ffff47a05',
#       'name': 'Coz Canler',
#       'roles': ['writer']},
#      {'mbid': '26f5cec0-6290-41d2-94d4-fef84f1abaff',
#       'name': 'Jimmy Marinos',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': '005ab68b-b440-45a0-a98f-0dabfd22afda',
#       'name': 'Mike Skill',
#       'roles': ['writer']},
#      {'mbid': '5ba24696-7699-4a7c-a0a9-622fe83b1c53',
#       'name': 'Peter Solley',
#       'roles': ['writer']},
#      {'mbid': '7c5b8865-d23c-4abf-884d-c68be0020991',
#       'name': 'Roland Orzabal',
#       'roles': ['writer']},
#      {'mbid': 'adaf0068-1c86-4166-8cee-f0a53f4854c4',
#       'name': 'Sir Dylan',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']},
#      {'mbid': 'a37eaea3-d23d-4c3c-9944-88e1dbfe6dc8',
#       'name': 'Wally Palmar',
#       'roles': ['writer']}]},
#    {'id': 13059913,
#     'name': 'True Colors',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7aa27474-7b32-46c5-a065-ec831e8a70da',
#       'name': 'Billy Walsh',
#       'roles': ['writer']},
#      {'mbid': '8fbcd70f-bf1e-4624-b94a-fcff6b0c637e',
#       'name': 'Cashmere Cat',
#       'roles': ['writer']},
#      {'mbid': '6fb8542b-1ddf-4a45-9c7f-57989eb0e1b0',
#       'name': 'Jake One',
#       'roles': ['writer']},
#      {'mbid': 'e96edb5d-52c3-4ba9-8097-9a4e8c5e2f88',
#       'name': 'Starrah',
#       'roles': ['writer']},
#      {'mbid': '3ad7ab3a-2399-41cb-835f-d1b4dd9d7d1c',
#       'name': 'Swish',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']},
#      {'mbid': '5a6131f9-f8db-4722-b4d7-6a0c7183c590',
#       'name': 'benny blanco',
#       'roles': ['writer']}]},
#    {'id': 13059914,
#     'name': 'Stargirl Interlude',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'dc99e6fd-c710-4f79-b74b-127b4d0b7849',
#       'name': 'Labrinth',
#       'roles': ['writer']},
#      {'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6',
#       'name': 'Lana Del Rey',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13059915,
#     'name': 'Sidewalks',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': 'd5ee9a6f-8e10-47e7-bca7-7e3f82aad769',
#       'name': 'Ali Shaheed Muhammad',
#       'roles': ['writer']},
#      {'mbid': 'b0d6d8f5-f83e-48c6-8581-748608958b11',
#       'name': 'Bobby Raps',
#       'roles': ['writer']},
#      {'mbid': '1cd2378c-2bff-4752-9321-178290cff0a6',
#       'name': 'Daniel Wilson',
#       'roles': ['writer']},
#      {'mbid': '381086ea-f511-4aba-bdf9-71c753dc5077',
#       'name': 'Kendrick Lamar',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13059916,
#     'name': 'Six Feet Under',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '64675ea9-686f-4de0-b001-aa425dba856a',
#       'name': 'Ben Billions',
#       'roles': ['writer']},
#      {'mbid': '0eb93ee5-2e6a-4ab4-a988-99c9139a664a',
#       'name': 'Cirkut',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '48262e82-db9f-4a92-b650-dfef979b73ec',
#       'name': 'Future',
#       'roles': ['writer']},
#      {'mbid': 'f15651b5-67ab-43f5-8bb6-5a1138759e9e',
#       'name': 'Martin “Doc” McKinney',
#       'roles': ['writer']},
#      {'mbid': '59db3d82-86ea-451f-881f-dffc8ec387c9',
#       'name': 'Metro Boomin',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13059917,
#     'name': 'Love to Lay',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '0edfb670-e666-41a6-b4e3-141d32944c9e',
#       'name': 'Ali Payami',
#       'roles': ['writer']},
#      {'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': '6622a50e-5206-44d0-9ad5-96047a726dcf',
#       'name': 'Max Martin',
#       'roles': ['writer']},
#      {'mbid': '160e6d77-4ad2-46c0-8bef-a456216c6354',
#       'name': 'Peter Svensson',
#       'roles': ['writer']},
#      {'mbid': 'c8af4490-e48a-4f91-aef9-2b1e39369576',
#       'name': 'Savan Kotecha',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13059918,
#     'name': 'A Lonely Night',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '0edfb670-e666-41a6-b4e3-141d32944c9e',
#       'name': 'Ali Payami',
#       'roles': ['writer']},
#      {'mbid': '7e302507-6b78-4f3b-9c4c-e3b85580fad0',
#       'name': 'Belly',
#       'roles': ['writer']},
#      {'mbid': 'd44ab93a-98c0-483f-ae58-8f9255f816d3',
#       'name': 'DaHeala',
#       'roles': ['writer']},
#      {'mbid': '6622a50e-5206-44d0-9ad5-96047a726dcf',
#       'name': 'Max Martin',
#       'roles': ['writer']},
#      {'mbid': '160e6d77-4ad2-46c0-8bef-a456216c6354',
#       'name': 'Peter Svensson',
#       'roles': ['writer']},
#      {'mbid': 'c8af4490-e48a-4f91-aef9-2b1e39369576',
#       'name': 'Savan Kotecha',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']}]},
#    {'id': 13059919,
#     'name': 'Attention',
#     'first_release_date': '2016-01-01',
#     'genres': [],
#     'collaborators': [{'mbid': '7aa27474-7b32-46c5-a065-ec831e8a70da',
#       'name': 'Billy Walsh',
#       'roles': ['writer']},
#      {'mbid': '8fbcd70f-bf1e-4624-b94a-fcff6b0c637e',
#       'name': 'Cashmere Cat',
#       'roles': ['writer']},
#      {'mbid': 'fb7d550f-7518-41ba-95db-33db5287d8e2',
#       'name': 'Frank Dukes',
#       'roles': ['writer']},
#      {'mbid': '4a5a5c9c-e569-4b94-960d-13f4a3730ea3',
#       'name': 'Mustafa Ahmed',
#       'roles': ['writer']},
#      {'mbid': 'c8b03190-306c-4120-bb0b-6f2ebfc06ea9',
#       'name': 'The Weeknd',
#       'roles': ['writer']},
# ...
#     'release_group_id': 2060497,
#     'label_ids': [UUID('82027a2f-e2ab-42db-859f-7a4aa5144d00')],
#     'label_names': ['Pop Art']},
#    {'id': 2292124,
#     'title': '80’s Symphonic',
#     'date': '2018-01-01',
#     'release_group_id': 2063417,
#     'label_ids': [UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4')],
#     'label_names': ['Rhino']},
#    {'id': 2312324,
#     'title': 'Take On Me (Symphonic version)',
#     'date': '2018-10-18',
#     'release_group_id': 2079121,
#     'label_ids': [UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4')],
#     'label_names': ['Rhino']},
#    {'id': 2734162,
#     'title': '80’s Symphonic',
#     'date': '2018-11-09',
#     'release_group_id': 2063417,
#     'label_ids': [UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4')],
#     'label_names': ['Rhino']},
#    {'id': 2778861,
#     'title': '80’s Symphonic',
#     'date': '2018-11-09',
#     'release_group_id': 2063417,
#     'label_ids': [UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4')],
#     'label_names': ['Rhino']},
#    {'id': 2293689,
#     'title': 'Listen With Smother',
#     'date': '1997-01-01',
#     'release_group_id': 2064634,
#     'label_ids': [UUID('ddc72240-faa5-4e81-a381-6cb4e3335d81')],
#     'label_names': ['Fierce Panda Records']},
#    {'id': 2296922,
#     'title': 'Music Featured in the Video Game: Metal Gear Solid V (Diamond Dogs Phantom Pain Playlist)',
#     'date': '2015-09-11',
#     'release_group_id': 2067123,
#     'label_ids': [UUID('6f06cf6d-8fcf-448a-907b-531302ce00a4')],
#     'label_names': ['Small Screen Music']},
#    {'id': 2307719,
#     'title': 'My Way, Vol. 1',
#     'date': '2018-03-23',
#     'release_group_id': 2075652,
#     'label_ids': [],
#     'label_names': []},
#    {'id': 4563643,
#     'title': 'My Way, Vol. 1 - EP',
#     'date': '2018-03-23',
#     'release_group_id': 2075652,
#     'label_ids': [UUID('157afde4-4bf5-4039-8ad2-5a15acc85176')],
#     'label_names': ['[no label]']},
#    {'id': 2043110,
#     'title': 'MTV Unplugged: Summer Solstice',
#     'date': '2017-10-06',
#     'release_group_id': 1866654,
#     'label_ids': [UUID('ce24ab18-1bd6-4293-a486-546d13d6a5e2'),
#      UUID('dfd92cd3-4888-46d2-b968-328b1feb2642')],
#     'label_names': ['Polydor', 'Island']},
#    {'id': 2051165,
#     'title': 'MTV Unplugged: Summer Solstice',
#     'date': '2017-10-06',
#     'release_group_id': 1866654,
#     'label_ids': [UUID('2c4b57e6-6f4a-4da7-8108-7b12271053da'),
#      UUID('ce24ab18-1bd6-4293-a486-546d13d6a5e2')],
#     'label_names': ['We Love Music', 'Polydor']},
#    {'id': 2310160,
#     'title': 'MTV Unplugged: Summer Solstice',
#     'date': '2017-10-06',
#     'release_group_id': 1866654,
#     'label_ids': [],
#     'label_names': []},
#    {'id': 4217993,
#     'title': 'MTV Unplugged: Summer Solstice',
#     'date': '2017-10-06',
#     'release_group_id': 1866654,
#     'label_ids': [UUID('19d052fa-570a-4b17-9a3d-8f2f029b7b57'),
#      UUID('2c4b57e6-6f4a-4da7-8108-7b12271053da'),
#      UUID('ce24ab18-1bd6-4293-a486-546d13d6a5e2')],
#     'label_names': ['Universal Music Group', 'We Love Music', 'Polydor']},
#    {'id': 2310331,
#     'title': 'Best Of',
#     'date': '2007-11-01',
#     'release_group_id': 2077657,
#     'label_ids': [UUID('eb4996de-5a12-4215-a592-940dff982655')],
#     'label_names': ['Yeah!Records']},
#    {'id': 2312801,
#     'title': 'Take on Me',
#     'date': '2017-09-29',
#     'release_group_id': 2079464,
#     'label_ids': [UUID('2c4b57e6-6f4a-4da7-8108-7b12271053da')],
#     'label_names': ['We Love Music']},
#    {'id': 2320370,
#     'title': 'Pediu pra sambar, Sambô (ao vivo)',
#     'date': '2016-09-02',
#     'release_group_id': 2085223,
#     'label_ids': [],
#     'label_names': []},
#    {'id': 3986831,
#     'title': 'Pediu pra sambar, Sambô (ao vivo)',
#     'date': '2016-09-02',
#     'release_group_id': 2085223,
#     'label_ids': [],
#     'label_names': []},
#    {'id': 2334603,
#     'title': 'Weezer',
#     'date': '2019-01-24',
#     'release_group_id': 2096485,
#     'label_ids': [UUID('1550cc00-ab45-45d3-90e0-0202103c8906'),
#      UUID('50c384a2-0b44-401b-b893-8181173339c7')],
#     'label_names': ['Crush Music', 'Atlantic']},
#    {'id': 2334604,
#     'title': 'Weezer',
#     'date': '2019-03-08',
#     'release_group_id': 2096485,
#     'label_ids': [UUID('1550cc00-ab45-45d3-90e0-0202103c8906')],
#     'label_names': ['Crush Music']},
#    {'id': 2338572,
#     'title': 'Weezer',
#     'date': '2019-01-24',
#     'release_group_id': 2096485,
#     'label_ids': [UUID('1550cc00-ab45-45d3-90e0-0202103c8906'),
#      UUID('50c384a2-0b44-401b-b893-8181173339c7')],
#     'label_names': ['Crush Music', 'Atlantic']},
#    {'id': 2374932,
#     'title': 'Weezer',
#     'date': '2019-03-08',
#     'release_group_id': 2096485,
#     'label_ids': [UUID('50c384a2-0b44-401b-b893-8181173339c7')],
#     'label_names': ['Atlantic']},
#    {'id': 2395742,
#     'title': 'Weezer',
#     'date': '2019-04-13',
#     'release_group_id': 2096485,
#     'label_ids': [UUID('1550cc00-ab45-45d3-90e0-0202103c8906')],
#     'label_names': ['Crush Music']},
#    {'id': 2423047,
#     'title': 'Weezer',
#     'date': '2019-05-17',
#     'release_group_id': 2096485,
#     'label_ids': [UUID('1550cc00-ab45-45d3-90e0-0202103c8906')],
#     'label_names': ['Crush Music']},
#    {'id': 3645358,
#     'title': 'Weezer',
#     'date': '2019-03-08',
#     'release_group_id': 2096485,
#     'label_ids': [UUID('1550cc00-ab45-45d3-90e0-0202103c8906')],
#     'label_names': ['Crush Music']},
#    {'id': 4833180,
#     'title': 'Weezer',
#     'date': '2022-12-30',
#     'release_group_id': 2096485,
#     'label_ids': [UUID('1550cc00-ab45-45d3-90e0-0202103c8906'),
#      UUID('50c384a2-0b44-401b-b893-8181173339c7')],
#     'label_names': ['Crush Music', 'Atlantic']},
#    {'id': 2337175,
#     'title': 'Absolutely Live',
#     'date': '2011-05-02',
#     'release_group_id': 2098500,
#     'label_ids': [UUID('157afde4-4bf5-4039-8ad2-5a15acc85176')],
#     'label_names': ['[no label]']},
#    {'id': 2345608,
#     'title': 'DMC Commercial Collection 213',
#     'date': '2000-10-01',
#     'release_group_id': 2105224,
#     'label_ids': [UUID('5f33772c-841c-4c2b-af0d-0570015beace')],
#     'label_names': ['DMC']},
#    {'id': 3001258,
#     'title': 'Sleeping Dogs Licensed Music',
#     'date': '2012-08-14',
#     'release_group_id': 2621095,
#     'label_ids': [],
#     'label_names': []},
#    {'id': 3622140,
#     'title': 'The Summer Breeze Collection',
#     'date': '2022-01-01',
#     'release_group_id': 3104173,
#     'label_ids': [UUID('4e0e831c-932b-4ba5-87f3-bec15ae18b25')],
#     'label_names': ['Direct Holdings Americas Inc.']},
#    {'id': 4231947,
#     'title': '80s Party: The Ultimate Collection',
#     'date': '2021-11-05',
#     'release_group_id': 3579934,
#     'label_ids': [UUID('0d200c19-fa2a-4eeb-a419-f5b9b89c8fa6'),
#      UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4')],
#     'label_names': ['Union Square Music', 'Rhino']},
#    {'id': 4289408,
#     'title': "Awesome 80's Hits",
#     'date': '2014-01-01',
#     'release_group_id': 3625190,
#     'label_ids': [UUID('2d079f15-8985-4e99-878e-eef16e07a421')],
#     'label_names': ['Green Hill']},
#    {'id': 4489754,
#     'title': '80s Music Hits',
#     'date': None,
#     'release_group_id': 3783631,
#     'label_ids': [],
#     'label_names': []},
#    {'id': 4501088,
#     'title': 'Essential 80’s',
#     'date': '2007-01-01',
#     'release_group_id': 3792372,
#     'label_ids': [UUID('f9ada3ae-3081-44df-8581-ca27a3462b68')],
#     'label_names': ['Sony BMG Music Entertainment']},
#    {'id': 4512757,
#     'title': 'Sleeping Dogs Unofficial Soundtrack Collection',
#     'date': '2014-04-30',
#     'release_group_id': 3801559,
#     'label_ids': [UUID('157afde4-4bf5-4039-8ad2-5a15acc85176')],
#     'label_names': ['[no label]']},
#    {'id': 4516496,
#     'title': 'Now That’s What I Call the 80s',
#     'date': '2024-09-06',
#     'release_group_id': 1591611,
#     'label_ids': [UUID('9e6b4d7f-4958-4db7-8504-d89e315836af'),
#      UUID('c029628b-6633-439e-bcee-ed02e8a338f7')],
#     'label_names': ['Sony Music', 'EMI']},
#    {'id': 4570632,
#     'title': 'NOW Presents: The 80s',
#     'date': '2024-09-06',
#     'release_group_id': 3848196,
#     'label_ids': [UUID('9e6b4d7f-4958-4db7-8504-d89e315836af'),
#      UUID('c029628b-6633-439e-bcee-ed02e8a338f7')],
#     'label_names': ['Sony Music', 'EMI']},
#    {'id': 4614016,
#     'title': 'Joe: Celebrate the 80’s',
#     'date': '2018-02-02',
#     'release_group_id': 3881822,
#     'label_ids': [UUID('1391bdc7-a22c-48a4-a5fb-e7b8ef6ce143')],
#     'label_names': ['Universal']},
#    {'id': 4676580,
#     'title': 'Totally 80s',
#     'date': '2005-01-01',
#     'release_group_id': 3931558,
#     'label_ids': [UUID('e8c184cf-9966-432e-80bb-5a44f7cd24f3'),
#      UUID('f6281082-8f72-437e-9814-942b1b30ccdd')],
#     'label_names': ['Platinum Legends', 'EMI Music Special Markets']},
#    {'id': 4713712,
#     'title': '100 Greatest Pop Songs',
#     'date': '2024-03-22',
#     'release_group_id': 3961969,
#     'label_ids': [UUID('29d4c4a9-3e05-4d57-9cd1-a7af0556bbd0')],
#     'label_names': ['X5 Music Group']},
#    {'id': 2404132,
#     'title': '101 Acoustic',
#     'date': '2018-05-18',
#     'release_group_id': 2153312,
#     'label_ids': [UUID('aec0386f-f228-4b5b-aeec-b84009f3e975')],
#     'label_names': ['UMC']},
#    {'id': 2416386,
#     'title': 'Take on Me',
#     'date': '2005-01-01',
#     'release_group_id': 2162915,
#     'label_ids': [UUID('f9e31d67-b9f4-4c36-91de-d7e4d015073c')],
#     'label_names': ['Double Dance Records']},
#    {'id': 2416388,
#     'title': 'Zombie / Take on Me',
#     'date': '2005-01-01',
#     'release_group_id': 2162917,
#     'label_ids': [UUID('f9e31d67-b9f4-4c36-91de-d7e4d015073c')],
#     'label_names': ['Double Dance Records']},
#    {'id': 2428645,
#     'title': 'Onwards and Upwards',
#     'date': '2019-05-24',
#     'release_group_id': 2172770,
#     'label_ids': [UUID('aad448fd-fd4c-421e-9e25-3722163afd6a')],
#     'label_names': ['ACT']},
#    {'id': 3022211,
#     'title': 'Onwards and Upwards',
#     'date': '2019-05-24',
#     'release_group_id': 2172770,
#     'label_ids': [UUID('aad448fd-fd4c-421e-9e25-3722163afd6a')],
#     'label_names': ['ACT']},
#    {'id': 2461873,
#     'title': 'Best Genesis Hits, Volume 1',
#     'date': '2015-06-30',
#     'release_group_id': 2198465,
#     'label_ids': [UUID('157afde4-4bf5-4039-8ad2-5a15acc85176')],
#     'label_names': ['[no label]']},
#    {'id': 2623077,
#     'title': 'Take On Me (Kygo remix)',
#     'date': '2015-08-26',
#     'release_group_id': 2199234,
#     'label_ids': [UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4'),
#      UUID('c595c289-47ce-4fba-b999-b87503e8cb71')],
#     'label_names': ['Rhino', 'Warner Bros. Records']},
#    {'id': 2625320,
#     'title': '100 Greatest Party Starters',
#     'date': '2019-11-15',
#     'release_group_id': 2324018,
#     'label_ids': [UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4')],
#     'label_names': ['Rhino']},
#    {'id': 2626987,
#     'title': 'Playlist: Party',
#     'date': '2019-12-27',
#     'release_group_id': 2325351,
#     'label_ids': [UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4')],
#     'label_names': ['Rhino']},
#    {'id': 2737503,
#     'title': 'Morning Songs',
#     'date': '2018-04-03',
#     'release_group_id': 2414425,
#     'label_ids': [UUID('29d4c4a9-3e05-4d57-9cd1-a7af0556bbd0')],
#     'label_names': ['X5 Music Group']},
#    {'id': 2741405,
#     'title': 'Sunday Morning Chill',
#     'date': '2018-10-05',
#     'release_group_id': 2417596,
#     'label_ids': [UUID('29d4c4a9-3e05-4d57-9cd1-a7af0556bbd0')],
#     'label_names': ['X5 Music Group']},
#    {'id': 2798235,
#     'title': 'Summer Dance Anthems',
#     'date': '2020-07-31',
#     'release_group_id': 2462036,
#     'label_ids': [UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4')],
#     'label_names': ['Rhino']},
#    {'id': 3218475,
#     'title': 'Pop Remixes',
#     'date': '2018-08-07',
#     'release_group_id': 2792983,
#     'label_ids': [UUID('29d4c4a9-3e05-4d57-9cd1-a7af0556bbd0')],
#     'label_names': ['X5 Music Group']},
#    {'id': 3339633,
#     'title': 'Paradise - Summer Feeling',
#     'date': '2021-06-18',
#     'release_group_id': 2885802,
#     'label_ids': [UUID('29d4c4a9-3e05-4d57-9cd1-a7af0556bbd0')],
#     'label_names': ['X5 Music Group']},
#    {'id': 3431656,
#     'title': 'These Days - Greatest Summer',
#     'date': '2021-06-18',
#     'release_group_id': 2957686,
#     'label_ids': [UUID('29d4c4a9-3e05-4d57-9cd1-a7af0556bbd0')],
#     'label_names': ['X5 Music Group']},
#    {'id': 3801044,
#     'title': '100 Greatest Summer Party Songs 2020',
#     'date': '2020-06-12',
#     'release_group_id': 3245762,
#     'label_ids': [UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4')],
#     'label_names': ['Rhino']},
#    {'id': 4503097,
#     'title': 'EDM',
#     'date': '2019-09-13',
#     'release_group_id': 3793936,
#     'label_ids': [UUID('29d4c4a9-3e05-4d57-9cd1-a7af0556bbd0')],
#     'label_names': ['X5 Music Group']},
#    {'id': 4504383,
#     'title': 'EDM Pop',
#     'date': '2019-07-26',
#     'release_group_id': 3794925,
#     'label_ids': [UUID('29d4c4a9-3e05-4d57-9cd1-a7af0556bbd0')],
#     'label_names': ['X5 Music Group']},
#    {'id': 4518727,
#     'title': '100 Greatest Dance Tracks',
#     'date': '2019-04-12',
#     'release_group_id': 3806357,
#     'label_ids': [UUID('c4f2cf49-b57c-4cc1-8061-f54400704ac4')],
#     'label_names': ['Rhino']},
#    {'id': 5189036,
#     'title': 'Periodic Table of Synthpop: Classic Songs, Modern Remixes 4',
#     'date': '2023-01-01',
#     'release_group_id': 4340163,
#     'label_ids': [UUID('8845ea34-db66-4180-a55d-aab0f91d7833')],
#     'label_names': ['Periodic Table of Synthpop']},
#    {'id': 4600806,
#     'title': 'Take On Me',
#     'date': '1984-01-01',
#     'release_group_id': 3871394,
#     'label_ids': [],
#     'label_names': []},
#    {'id': 2507033,
#     'title': '8-Bit New Wave',
#     'date': '2019-01-04',
#     'release_group_id': 2233416,
#     'label_ids': [],
#     'label_names': []},
#    {'id': 2533576,
#     'title': '80’s Grandmaster',
#     'date': '1998-01-01',
#     'release_group_id': 2253771,
#     'label_ids': [UUID('8e0090e8-9081-4797-a386-990040f0accf')],
#     'label_names': ['Music Factory']},
#    {'id': 2574834,
#     'title': 'NOW That’s What I Call 80s Hits & Remixes',
#     'date': '2019-10-25',
#     'release_group_id': 2285385,
#     'label_ids': [UUID('19d052fa-570a-4b17-9a3d-8f2f029b7b57'),
#      UUID('9e6b4d7f-4958-4db7-8504-d89e315836af')],
#     'label_names': ['Universal Music Group', 'Sony Music']},
#    {'id': 2720606,
#     'title': 'NOW That’s What I Call 80s Hits & Remixes',
#     'date': '2019-10-25',
#     'release_group_id': 2285385,
#     'label_ids': [],
#     'label_names': []},
#    {'id': 4223826,
#     'title': 'Throwback 80s',
#     'date': '2022-02-04',
#     'release_group_id': 3573618,
#     'label_ids': [UUID('29d4c4a9-3e05-4d57-9cd1-a7af0556bbd0')],
#     'label_names': ['X5 Music Group']},
#    {'id': 2583465,
#     'title': 'Trevor Horn Reimagines the Eighties',
#     'date': '2019-01-25',
#     'release_group_id': 2292084,
#     'label_ids': [UUID('82ef9b02-7b42-49fe-a6bc-0d8ba816d72f')],
#     'label_names': ['BMG']},
#    {'id': 3615401,
#     'title': 'Trevor Horn Reimagines the Eighties',
#     'date': '2019-01-25',
#     'release_group_id': 2292084,
#     'label_ids': [UUID('82ef9b02-7b42-49fe-a6bc-0d8ba816d72f')],
#     'label_names': ['BMG']},
#    {'id': 3882503,
#     'title': 'Trevor Horn Reimagines the Eighties',
#     'date': '2019-01-25',
#     'release_group_id': 2292084,
#     'label_ids': [UUID('7b228c4d-659e-4983-bf1b-20f2deec3cc9')],
#     'label_names': ['U/M/A/A']},
#    {'id': 2614504,
#     'title': 'Under the Covers',
#     'date': '2019-10-10',
#     'release_group_id': 2315557,
#     'label_ids': [UUID('e0dac49c-2ce7-4194-9922-35dabc5fa1df')],
#     'label_names': ['Leftfield Media']},
#    {'id': 2638780,
#     'title': 'Blast from the Grassed',
#     'date': '2020-02-14',
#     'release_group_id': 2334903,
#     'label_ids': [],
#     'label_names': []},
#    {'id': 2642545,
#     'title': 'SuperWeihnachten*: 38 aktuelle Hits zum Reinhören!',
#     'date': '2001-01-01',
#     'release_group_id': 2338032,
#     'label_ids': [UUID('918af229-7b78-4251-b003-8e2781812c82')],
#     'label_names': ['Universal Marketing Group']},
#    {'id': 2647362,
#     'title': 'Cover-Up, Vol. IV',
#     'date': '2019-04-24',
#     'release_group_id': 2341921,
#     'label_ids': [UUID('157afde4-4bf5-4039-8ad2-5a15acc85176')],
#     'label_names': ['[no label]']},
#    ...]}]

# %%
with open('data/from_1000_expanded_mbids.txt') as f:
    mbid_list = f.read().splitlines()

# %%
reload(mb)
# Out:
# <module 'apis.musicbrainz' from '/home/woodbkb2/git/nepo-music/apis/musicbrainz.py'>

# %%
mucho_data = list(mb.stream_artists_songs_by_mbids(mbid_list[:10]))

# %%
import base_model.features_calculator as fc

# %%
features = fc.compute_mb_artist_early_features(mucho_data[0])

# %%
features
# Out:
# {'artist_mbid': '777a21a8-0d0f-4cf3-86b4-65bc0eba5649',
#  'artist_name': 'Staind',
#  'window_years': 3,
#  'debut_date': '1979-01-01',
#  'window_cutoff_date': '1982-01-01',
#  'releases_total': 16,
#  'releases_per_year': 5.3321167883211675,
#  'avg_days_between_releases': 24.333333333333332,
#  'release_velocity_releases_per_day': 0.02365409868084471,
#  'release_velocity_releases_per_year': 8.63965954317853,
#  'gap_median_days': 0.0,
#  'gap_std_days': 82.87795578774585,
#  'max_dry_spell_days': 333,
#  'front_loading_index': 1.0,
#  'tracks_total': 16,
#  'collab_track_rate': 1.0,
#  'unique_collaborator_count': 2,
#  'label_diversity_count': 6,
#  'label_churn': 11,
#  'label_hhi': 0.2109375,
#  'duration_ms_mean': 373400.0,
#  'duration_ms_median': 383000.0,
#  'duration_ms_min': 239000,
#  'duration_ms_max': 383000,
#  'remix_rate': 0.0,
#  'acoustic_rate': 0.0,
#  'genre_count': 4,
#  'genre_entropy': 1.3862943611198906}

# %%
import apis.spotify as sp

# %%
artist_resource_information = list(mb.stream_artist_resources(mbid_list[:10]))
artist_resource_information[1]
# Out:
# (UUID('0c3505e7-d884-43cf-9028-d318607190a4'),
#  [{'link_type': 'social network', 'url': 'https://twitter.com/azealiabanks'},
#   {'link_type': 'last.fm', 'url': 'https://www.last.fm/music/Azealia+Banks'},
#   {'link_type': 'free streaming',
#    'url': 'https://open.spotify.com/artist/7gRhy3MIPHQo5CXYfWaw9I'},
#   {'link_type': 'social network',
#    'url': 'https://www.instagram.com/azealiabanks/'},
#   {'link_type': 'soundcloud', 'url': 'https://soundcloud.com/azealia-banks'},
#   {'link_type': 'social network', 'url': 'https://twitter.com/Azealiaishere'},
#   {'link_type': 'youtube',
#    'url': 'https://www.youtube.com/channel/UCD4UMQ7oryQQq5gqZStJQ6g'},
#   {'link_type': 'youtube',
#    'url': 'https://www.youtube.com/channel/UCPR8RgeVZjJ3ogh45KyepCg'}])

# %%
spotify_artists = {
    str(resource_set[0]): resource_set[1] for resource_set in artist_resource_information if any('spotify' in resource['url'] for resource in resource_set[1])
}

# %%
spotify_artists
# Out:
# {'04bac789-bf59-4383-8ad7-799d20d969f7': [{'link_type': 'youtube',
#    'url': 'https://www.youtube.com/channel/UC74sX8oY-MVC7_3KzlnFgzQ'},
#   {'link_type': 'last.fm', 'url': 'https://www.last.fm/music/Modjo'},
#   {'link_type': 'free streaming',
#    'url': 'https://open.spotify.com/artist/0AkpPlFLnr0VQwZQeMGht0'}],
#  '0c3505e7-d884-43cf-9028-d318607190a4': [{'link_type': 'social network',
#    'url': 'https://twitter.com/azealiabanks'},
#   {'link_type': 'last.fm', 'url': 'https://www.last.fm/music/Azealia+Banks'},
#   {'link_type': 'free streaming',
#    'url': 'https://open.spotify.com/artist/7gRhy3MIPHQo5CXYfWaw9I'},
#   {'link_type': 'social network',
#    'url': 'https://www.instagram.com/azealiabanks/'},
#   {'link_type': 'soundcloud', 'url': 'https://soundcloud.com/azealia-banks'},
#   {'link_type': 'social network', 'url': 'https://twitter.com/Azealiaishere'},
#   {'link_type': 'youtube',
#    'url': 'https://www.youtube.com/channel/UCD4UMQ7oryQQq5gqZStJQ6g'},
#   {'link_type': 'youtube',
#    'url': 'https://www.youtube.com/channel/UCPR8RgeVZjJ3ogh45KyepCg'}],
#  '777a21a8-0d0f-4cf3-86b4-65bc0eba5649': [{'link_type': 'youtube',
#    'url': 'https://www.youtube.com/user/staindvideos'},
#   {'link_type': 'free streaming',
#    'url': 'https://open.spotify.com/artist/5KDIH2gF0VpelTqyQS7udb'},
#   {'link_type': 'social network', 'url': 'https://twitter.com/staind'},
#   {'link_type': 'last.fm', 'url': 'https://www.last.fm/music/Staind'},
#   {'link_type': 'soundcloud', 'url': 'https://soundcloud.com/staindofficial'},
#   {'link_type': 'social network',
#    'url': 'https://www.instagram.com/officialstaind/'}],
#  '89aa5ecb-59ad-46f5-b3eb-2d424e941f19': [{'link_type': 'free streaming',
#    'url': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#   {'link_type': 'social network',
#    'url': 'https://www.instagram.com/badbunnypr/'},
#   {'link_type': 'social network', 'url': 'https://twitter.com/sanbenito'},
#   {'link_type': 'youtube',
#    'url': 'https://www.youtube.com/channel/UCmBA_wu8xGg1OfOkfW13Q0Q'},
#   {'link_type': 'soundcloud', 'url': 'https://soundcloud.com/badbunny15'},
#   {'link_type': 'last.fm', 'url': 'https://www.last.fm/music/Bad+Bunny'}]}

# %%
reload(sp)
# Out:
# <module 'apis.spotify' from '/home/woodbkb2/git/nepo-music/apis/spotify.py'>

# %%
features
# Out:
# {'artist_mbid': '777a21a8-0d0f-4cf3-86b4-65bc0eba5649',
#  'artist_name': 'Staind',
#  'window_years': 3,
#  'debut_date': '1979-01-01',
#  'window_cutoff_date': '1982-01-01',
#  'releases_total': 16,
#  'releases_per_year': 5.3321167883211675,
#  'avg_days_between_releases': 24.333333333333332,
#  'release_velocity_releases_per_day': 0.02365409868084471,
#  'release_velocity_releases_per_year': 8.63965954317853,
#  'gap_median_days': 0.0,
#  'gap_std_days': 82.87795578774585,
#  'max_dry_spell_days': 333,
#  'front_loading_index': 1.0,
#  'tracks_total': 16,
#  'collab_track_rate': 1.0,
#  'unique_collaborator_count': 2,
#  'label_diversity_count': 6,
#  'label_churn': 11,
#  'label_hhi': 0.2109375,
#  'duration_ms_mean': 373400.0,
#  'duration_ms_median': 383000.0,
#  'duration_ms_min': 239000,
#  'duration_ms_max': 383000,
#  'remix_rate': 0.0,
#  'acoustic_rate': 0.0,
#  'genre_count': 4,
#  'genre_entropy': 1.3862943611198906,
#  'num_followers': 2975069}

# %%
filtered_artist_features = [fc.compute_mb_artist_early_features(artist_data) for artist_data in mucho_data]

# %%
filtered_artist_features
# Out:
# [{'artist_mbid': '777a21a8-0d0f-4cf3-86b4-65bc0eba5649',
#   'artist_name': 'Staind',
#   'window_years': 3,
#   'debut_date': '1979-01-01',
#   'window_cutoff_date': '1982-01-01',
#   'releases_total': 16,
#   'releases_per_year': 5.3321167883211675,
#   'avg_days_between_releases': 24.333333333333332,
#   'release_velocity_releases_per_day': 0.02365409868084471,
#   'release_velocity_releases_per_year': 8.63965954317853,
#   'gap_median_days': 0.0,
#   'gap_std_days': 82.87795578774585,
#   'max_dry_spell_days': 333,
#   'front_loading_index': 1.0,
#   'tracks_total': 16,
#   'collab_track_rate': 1.0,
#   'unique_collaborator_count': 2,
#   'label_diversity_count': 6,
#   'label_churn': 11,
#   'label_hhi': 0.2109375,
#   'duration_ms_mean': 373400.0,
#   'duration_ms_median': 383000.0,
#   'duration_ms_min': 239000,
#   'duration_ms_max': 383000,
#   'remix_rate': 0.0,
#   'acoustic_rate': 0.0,
#   'genre_count': 4,
#   'genre_entropy': 1.3862943611198906},
#  {'artist_mbid': '703c557f-82bb-4646-ae2f-b5a3ef3f6148',
#   'artist_name': 'Jennifer Skillman',
#   'window_years': 3,
#   'debut_date': '2012-01-01',
#   'window_cutoff_date': '2015-01-01',
#   'releases_total': 16,
#   'releases_per_year': 5.3321167883211675,
#   'avg_days_between_releases': 34.13333333333333,
#   'release_velocity_releases_per_day': 0.028016274049738023,
#   'release_velocity_releases_per_year': 10.232944096666813,
#   'gap_median_days': 4.0,
#   'gap_std_days': 79.67004176951055,
#   'max_dry_spell_days': 323,
#   'front_loading_index': 1.0,
#   'tracks_total': 31,
#   'collab_track_rate': 1.0,
#   'unique_collaborator_count': 13,
#   'label_diversity_count': 7,
#   'label_churn': 7,
#   'label_hhi': 0.421875,
#   'duration_ms_mean': 230273.2258064516,
#   'duration_ms_median': 200120.0,
#   'duration_ms_min': 197266,
#   'duration_ms_max': 421000,
#   'remix_rate': 0.22580645161290322,
#   'acoustic_rate': 0.0,
#   'genre_count': 0,
#   'genre_entropy': None},
#  {'artist_mbid': '25848dee-8562-4a78-b375-3a80b61da629',
#   'artist_name': 'Wally Badarou',
#   'window_years': 3,
#   'debut_date': '1980-01-01',
#   'window_cutoff_date': '1983-01-01',
#   'releases_total': 15,
#   'releases_per_year': 4.998859489051094,
#   'avg_days_between_releases': 56.42857142857143,
#   'release_velocity_releases_per_day': 0.014099026834902533,
#   'release_velocity_releases_per_year': 5.1496695514481505,
#   'gap_median_days': 0.0,
#   'gap_std_days': 94.5913876219442,
#   'max_dry_spell_days': 311,
#   'front_loading_index': 0.5333333333333333,
#   'tracks_total': 39,
#   'collab_track_rate': 0.9230769230769231,
#   'unique_collaborator_count': 10,
#   'label_diversity_count': 3,
#   'label_churn': 4,
#   'label_hhi': 0.76,
#   'duration_ms_mean': 315367.3157894737,
#   'duration_ms_median': 305600.0,
#   'duration_ms_min': 55000,
#   'duration_ms_max': 464760,
#   'remix_rate': 0.05128205128205128,
#   'acoustic_rate': 0.0,
#   'genre_count': 0,
#   'genre_entropy': None},
#  {'artist_mbid': '3e7bcc53-53d4-41d8-afbc-69f82b858fd9',
#   'artist_name': 'Carl Rosen',
#   'window_years': 3,
#   'debut_date': '2017-09-15',
#   'window_cutoff_date': '2020-09-15',
#   'releases_total': 205,
#   'releases_per_year': 68.31774635036496,
#   'avg_days_between_releases': 5.284313725490196,
#   'release_velocity_releases_per_day': 0.24557471875679052,
#   'release_velocity_releases_per_year': 89.69616602591773,
#   'gap_median_days': 0.0,
#   'gap_std_days': 11.639080088793143,
#   'max_dry_spell_days': 100,
#   'front_loading_index': 0.4634146341463415,
#   'tracks_total': 219,
#   'collab_track_rate': 1.0,
#   'unique_collaborator_count': 28,
#   'label_diversity_count': 59,
#   'label_churn': 147,
#   'label_hhi': 0.07420408412441622,
#   'duration_ms_mean': 186072.21559633026,
#   'duration_ms_median': 181000.0,
#   'duration_ms_min': 139000,
#   'duration_ms_max': 264000,
#   'remix_rate': 0.0730593607305936,
#   'acoustic_rate': 0.0045662100456621,
#   'genre_count': 0,
#   'genre_entropy': None},
#  {'artist_mbid': '43a0ce3a-a3d5-45c0-b944-bd8f5e021237',
#   'artist_name': 'Nolan Sipe',
#   'window_years': 3,
#   'debut_date': '2014-01-01',
#   'window_cutoff_date': '2017-01-01',
#   'releases_total': 48,
#   'releases_per_year': 15.996350364963503,
#   'avg_days_between_releases': 22.680851063829788,
#   'release_velocity_releases_per_day': 0.04893635715015851,
#   'release_velocity_releases_per_year': 17.874004449095395,
#   'gap_median_days': 4.0,
#   'gap_std_days': 33.190043612812126,
#   'max_dry_spell_days': 114,
#   'front_loading_index': 0.2916666666666667,
#   'tracks_total': 53,
#   'collab_track_rate': 1.0,
#   'unique_collaborator_count': 25,
#   'label_diversity_count': 24,
#   'label_churn': 32,
#   'label_hhi': 0.06625,
#   'duration_ms_mean': 199303.5849056604,
#   'duration_ms_median': 199000.0,
#   'duration_ms_min': 148000,
#   'duration_ms_max': 216381,
#   'remix_rate': 0.0,
#   'acoustic_rate': 0.018867924528301886,
#   'genre_count': 0,
#   'genre_entropy': None},
#  {'artist_mbid': '89aa5ecb-59ad-46f5-b3eb-2d424e941f19',
#   'artist_name': 'Bad Bunny',
#   'window_years': 3,
#   'debut_date': '2016-12-08',
#   'window_cutoff_date': '2019-12-08',
#   'releases_total': 47,
#   'releases_per_year': 15.677397260273974,
#   'avg_days_between_releases': 21.217391304347824,
#   'release_velocity_releases_per_day': 0.06287157029506718,
#   'release_velocity_releases_per_year': 22.963841050273288,
#   'gap_median_days': 7.5,
#   'gap_std_days': 37.454269532834104,
#   'max_dry_spell_days': 220,
#   'front_loading_index': 0.425531914893617,
#   'tracks_total': 51,
#   'collab_track_rate': 0.8627450980392157,
#   'unique_collaborator_count': 18,
#   'label_diversity_count': 24,
#   'label_churn': 32,
#   'label_hhi': 0.11124330755502679,
#   'duration_ms_mean': 225790.86,
#   'duration_ms_median': 241525.0,
#   'duration_ms_min': 144606,
#   'duration_ms_max': 417000,
#   'remix_rate': 0.13725490196078433,
#   'acoustic_rate': 0.0,
#   'genre_count': 2,
#   'genre_entropy': 0.6931471805599453},
#  {'artist_mbid': '0c3505e7-d884-43cf-9028-d318607190a4',
#   'artist_name': 'Azealia Banks',
#   'window_years': 3,
#   'debut_date': '1944-11-02',
#   'window_cutoff_date': '1947-11-02',
#   'releases_total': 1,
#   'releases_per_year': 0.3335616438356165,
#   'avg_days_between_releases': None,
#   'release_velocity_releases_per_day': None,
#   'release_velocity_releases_per_year': None,
#   'gap_median_days': None,
#   'gap_std_days': None,
#   'max_dry_spell_days': None,
#   'front_loading_index': 1.0,
#   'tracks_total': 1,
#   'collab_track_rate': 1.0,
#   'unique_collaborator_count': 2,
#   'label_diversity_count': 1,
#   'label_churn': 0,
#   'label_hhi': 1.0,
#   'duration_ms_mean': 163800.0,
#   'duration_ms_median': 163800.0,
#   'duration_ms_min': 163800,
#   'duration_ms_max': 163800,
#   'remix_rate': 0.0,
#   'acoustic_rate': 0.0,
#   'genre_count': 6,
#   'genre_entropy': 1.7917594692280547},
#  {'artist_mbid': '04bac789-bf59-4383-8ad7-799d20d969f7',
#   'artist_name': 'Modjo',
#   'window_years': 3,
#   'debut_date': '2000-01-01',
#   'window_cutoff_date': '2003-01-01',
#   'releases_total': 81,
#   'releases_per_year': 26.99384124087591,
#   'avg_days_between_releases': 12.2375,
#   'release_velocity_releases_per_day': 0.09009520803528757,
#   'release_velocity_releases_per_year': 32.90727473488879,
#   'gap_median_days': 0.0,
#   'gap_std_days': 29.222954911336394,
#   'max_dry_spell_days': 182,
#   'front_loading_index': 0.7283950617283951,
#   'tracks_total': 147,
#   'collab_track_rate': 1.0,
#   'unique_collaborator_count': 2,
#   'label_diversity_count': 40,
#   'label_churn': 66,
#   'label_hhi': 0.05422222222222223,
#   'duration_ms_mean': 273178.2108843537,
#   'duration_ms_median': 228000.0,
#   'duration_ms_min': 93026,
#   'duration_ms_max': 510000,
#   'remix_rate': 0.06802721088435375,
#   'acoustic_rate': 0.10884353741496598,
#   'genre_count': 2,
#   'genre_entropy': 0.6931471805599453},
#  {'artist_mbid': 'e99e2c02-0ca7-4687-897c-efedbe5b98c2',
#   'artist_name': 'Leon Michels',
#   'window_years': 3,
#   'debut_date': '2007-01-01',
#   'window_cutoff_date': '2010-01-01',
#   'releases_total': 60,
#   'releases_per_year': 19.995437956204377,
#   'avg_days_between_releases': 18.423728813559322,
#   'release_velocity_releases_per_day': 0.06516655970930471,
#   'release_velocity_releases_per_year': 23.802085933823545,
#   'gap_median_days': 0.0,
#   'gap_std_days': 50.001763829848535,
#   'max_dry_spell_days': 309,
#   'front_loading_index': 0.36666666666666664,
#   'tracks_total': 67,
#   'collab_track_rate': 1.0,
#   'unique_collaborator_count': 19,
#   'label_diversity_count': 19,
#   'label_churn': 41,
#   'label_hhi': 0.10267857142857142,
#   'duration_ms_mean': 217481.4328358209,
#   'duration_ms_median': 208893.0,
#   'duration_ms_min': 179853,
#   'duration_ms_max': 266000,
#   'remix_rate': 0.029850746268656716,
#   'acoustic_rate': 0.0,
#   'genre_count': 0,
#   'genre_entropy': None},
#  {'artist_mbid': '5ab9fb83-59da-4510-941e-fd42189199aa',
#   'artist_name': 'James “Nard” Rosser',
#   'window_years': 3,
#   'debut_date': '2008-01-01',
#   'window_cutoff_date': '2011-01-01',
#   'releases_total': 9,
#   'releases_per_year': 2.9993156934306566,
#   'avg_days_between_releases': 64.375,
#   'release_velocity_releases_per_day': 0.016465719798899988,
#   'release_velocity_releases_per_year': 6.01410415654822,
#   'gap_median_days': 5.5,
#   'gap_std_days': 99.96116433395521,
#   'max_dry_spell_days': 272,
#   'front_loading_index': 1.0,
#   'tracks_total': 9,
#   'collab_track_rate': 1.0,
#   'unique_collaborator_count': 5,
#   'label_diversity_count': 2,
#   'label_churn': 3,
#   'label_hhi': 0.5061728395061729,
#   'duration_ms_mean': 299627.8888888889,
#   'duration_ms_median': 300093.0,
#   'duration_ms_min': 265000,
#   'duration_ms_max': 331000,
#   'remix_rate': 0.0,
#   'acoustic_rate': 0.0,
#   'genre_count': 0,
#   'genre_entropy': None}]

# %%
for feature_set in filtered_artist_features:
    artist_mbid = feature_set['artist_mbid']
    if artist_mbid not in spotify_artists:
        continue
    resource_info = spotify_artists[artist_mbid]
    spotify_id = [resource['url'] for resource in resource_info if 'spotify' in resource['url']][0].split('/')[-1]
    feature_set['num_followers'] = sp.get_artist_followers(spotify_id)

# %%
import json
import os

# %%
os.makedirs('data/artist_full_data/', exist_ok=True)

# %%
with open('data/artist_full_data/example_base_dataset_structure.json','w') as f:
    f.write(json.dumps(filtered_artist_features))

# %%
with open('data/artist_full_data/example_base_dataset_structure.json','r') as f:
    filtered_artist_features = json.load(f)
