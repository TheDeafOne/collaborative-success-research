# %%
import json
import os

# %%
os.chdir('..')

# %%
with open('data/artist_works.json') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'artist_mbid': '10adbe5e-a2c0-4bf3-8249-2b4cbf6e6ca8',
#   'works': [{'song_title': 'Red Light',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['10adbe5e-a2c0-4bf3-8249-2b4cbf6e6ca8']}]},
#  {'artist_mbid': '72c536dc-7137-4477-a521-567eeb840fa8',
#   'works': [{'song_title': "(We're Living on) Borrowed Time",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': '10,000 Men',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': '2 Dollars and 99 Cents',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': '2 x 2',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': '4th Time Around',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'A Better World / The Times They Are a Changin’',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '7f022f96-2cab-487a-bafe-8ee9a8aa2d18']},
#    {'song_title': 'A Gwn Fod Popeth Yn Iawn',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['012f4bf6-4040-42c9-a7d0-6e72463d1f65',
#      '72c536dc-7137-4477-a521-567eeb840fa8',
#      '9be7f096-97ec-4615-8957-8d40b5dcbc41']},
#    {'song_title': 'A Story of East Orange, New Jersey',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Abandoned Love',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Absolutely Fabulous',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['39d5615d-1418-4b80-85aa-214eaac7cfb2',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Absolutely Sweet Marie',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Achilles',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Adam dał imiona zwierzętom',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Adieu Angelina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Adios, Angelina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Adjö Angelina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Afternoon',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'ed07a418-7721-4617-af06-d07c5d5e97ff']},
#    {'song_title': 'Ah Ah Ah',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Ain't No Man Righteous, No Not One",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ain’t Gonna Go to Hell for Anybody',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ain’t Gonna Grieve',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ain’t Talkin’',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Air to Breathe',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Aizvējā',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['3a83748e-f29b-4a86-8cb9-e499a7b0d31a',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Akkurat som ei dame',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Alaska Quinn',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['043f1dfd-46d1-4414-aea9-f71f71cd4156',
#      '6e8f6293-ad08-4e50-96f3-6437630c0c39',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'All Along the Watchtower',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'All American Boy',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'b7798819-d9b2-442b-bd22-e55b40a1a69f']},
#    {'song_title': 'All American Boy',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['12a08d78-afce-4626-8516-f3eb685aece5',
#      '72c536dc-7137-4477-a521-567eeb840fa8',
#      '75048a5f-2600-49a4-a95a-c9a979c5746a']},
#    {'song_title': 'All I Really Want to Do',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'All Over You',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'All the Tired Horses',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'All the Way',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'All the Way Down',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Allan wia a Stan',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Allra minst en morgon',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Allt det handlar om för mej',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Allting syns på svart',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ally McBeal',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'c88a95b4-1c26-4bfc-aef8-49004c2a00ac']},
#    {'song_title': 'Almost Persuaded',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Alright',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Als ob se'n Frau wöhr",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Alt som var er over, søster blå',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Alt und jung',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "And He's Killed Me Too–Billy (reprise)",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Angelina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Angelina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Another Love Song',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Any Time',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Apothecary',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Apple Suckling Tree',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Are You Ready?',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Arlekin',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'As I Went Out One Morning',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'As We Sailed Into Skibbereen',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'fa3b535a-9da9-4d85-9a16-91811ad61ad2']},
#    {'song_title': 'Au cœur de mon pays',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['668fd73c-bf54-4310-a139-305517f05311',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Avventura a Durango',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'b22def9d-813a-47f2-ae21-96b144d8e91c']},
#    {'song_title': 'B.U.P.',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Baby Give It Up',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'ed07a418-7721-4617-af06-d07c5d5e97ff']},
#    {'song_title': "Baby I'm in the Wind",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Baby Stop Crying',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Baby, I'm in the Mood for You",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Baby, I’m in the Mood for You',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Baby, Let Me Follow You Down',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '9be7f096-97ec-4615-8957-8d40b5dcbc41',
#      'd9109c45-ddf6-4481-89ee-d6bee8306db3',
#      'f6639920-db09-4e37-a6d9-f036a37e095c',
#      'f66eefea-ff87-46b5-947d-b595a4bac5c9']},
#    {'song_title': 'Ballad for a Friend',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ballad in Plain D',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ballad of Donald White',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ballad of Easy Rider',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['6ec7336b-a56a-4b5d-bcec-575d2b8ed4e1',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ballad of Hollis Brown',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ballad of a Thin Man',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ballad of the Gliding Swan',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'ee8581a2-6be6-4979-9348-5cf9a411cd08']},
#    {'song_title': 'Ballada o cieniasie',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ballade de Hollis Brown',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Band of the Hand (It’s Hell Time, Man!)',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Be Careful (I Don’t Care)',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Behalt’s für mich',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Bell Tower Blues',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Better Have It All',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Beyond Here Lies Nothin’',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'e9b419b5-ab8f-425c-8214-a7259e6efe10']},
#    {'song_title': 'Beyond the Horizon',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'd90809e8-c72f-4142-9068-a19feffe0f42']},
#    {'song_title': 'Bez słowa',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Big Black Train',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'b068b235-8455-430e-8f52-0d1161e3d730']},
#    {'song_title': 'Big City Blues',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Big Dog',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Billy',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Billy',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Billy 1',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Billy 4',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Billy 7',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Billy's Surrender",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Black Crow Blues',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Black Diamond Bay',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'b22def9d-813a-47f2-ae21-96b144d8e91c']},
#    {'song_title': 'Black Rider',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Blessed Is the Name',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Blind Willie McTell',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Blinde Will McTell',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Blowin’ in the Wind',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Blowin’ in the Wind',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Bob Dylan’s 115th Dream',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Bob Dylan’s Blues',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Bob Dylan’s Dream',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Bob Dylan’s New Orleans Rag',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Bonnie, Why'd You Cut My Hair?",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '9be7f096-97ec-4615-8957-8d40b5dcbc41']},
#    {'song_title': 'Boots of Spanish Leather',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Born in Time',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Bottleneck Polka',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Bound to Lose, Bound to Win',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'cbd827e1-4e38-427e-a436-642683433732']},
#    {'song_title': 'Bourbon Street',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Bowling Alley Blues',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Broadway Strut',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Brown Skin Girl',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'ed07a418-7721-4617-af06-d07c5d5e97ff']},
#    {'song_title': 'Brownsville Girl',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'b9afb910-1f9e-46fc-9806-df8f49015568']},
#    {'song_title': 'Buckets of Rain',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Bunkhouse Theme',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Burza',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Bye and Bye',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'California',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'California Brown-Eyed Baby',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Call Letter Blues',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Can You Please Crawl Out Your Window?',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Can't Escape From You",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Can't Wait",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Cantina Theme (Workin' for the Law)",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Caribbean Wind',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Cat's in the Well",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Catfish',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'b22def9d-813a-47f2-ae21-96b144d8e91c']},
#    {'song_title': 'Cauchemar psychomoteur',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Ce que je veux surtout',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Cellar Instrumental Number 1',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Chambermaid',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '91731dfa-eaa9-44aa-97b5-949f0512148f',
#      'cf119120-7df5-47d7-9dec-49f8837a4e40']},
#    {'song_title': 'Champaign, Illinois',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['068bd7ab-c38e-4fae-8ed2-cb0c153ed68f',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Champaign, Illinois',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'bb861349-25f2-4e90-ab38-bde20ef9849e']},
#    {'song_title': 'Changing of the Guards',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Chaufför',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Chicago After Dark',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Child to Me',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Chimes of Freedom',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Chippendale',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Church With No Upstairs',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'City of Gold',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Clean Cut Kid',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Cloches sonnez',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Clothes Line Saga',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Cocaine Blues',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '9be7f096-97ec-4615-8957-8d40b5dcbc41']},
#    {'song_title': 'Cold Irons Bound',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Coming From the Heart (The Road Is Long)',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'ed07a418-7721-4617-af06-d07c5d5e97ff']},
#    {'song_title': 'Comme Blind Willie Mc Tell',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Comme des pierres qui roulent',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Comme une femme',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Congratulations',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['0bbbc496-c7b5-4b3f-bb6d-bd312827d6e5',
#      '372304d0-5e6a-4030-bc2b-09bdb0ee8abb',
#      '42a8f507-8412-4611-854f-926571049fa0',
#      '5ca3f318-d028-4151-ac73-78e2b2d6cdcc',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Connecticut Cowboy',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Cool Dry Place',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['372304d0-5e6a-4030-bc2b-09bdb0ee8abb',
#      '42a8f507-8412-4611-854f-926571049fa0',
#      '5ca3f318-d028-4151-ac73-78e2b2d6cdcc',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Corrina Corrina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '8a8bbba6-72f7-4900-a306-c40b94f2631b']},
#    {'song_title': 'Corrina, Corrina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '8a8bbba6-72f7-4900-a306-c40b94f2631b',
#      '9be7f096-97ec-4615-8957-8d40b5dcbc41']},
#    {'song_title': 'Corrina, Corrina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '8a8bbba6-72f7-4900-a306-c40b94f2631b',
#      '9be7f096-97ec-4615-8957-8d40b5dcbc41']},
#    {'song_title': 'Country Pie',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Covenant Woman',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Cover Down, Break Through',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Cowboy Angel Blues…',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Crash on the Levee (Down in the Flood)',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Cross-Wind Jamboree',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Crossing The Rubicon',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Cry a While',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Czas mija z wolna',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Czasy nadchodzą nowe',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "D'être à vous",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Da Mensch in mir',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dagen är kommen',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Damer i regn',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dan ga ik weg voorgoed',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dans le souffle du vent',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dark Eyes',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dark Groove',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dat benn ich nit',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Day of the Locusts',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'De wonde die nooit heelt',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dead Man, Dead Man',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dear Landlord',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Death Is Not the End',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Demain c'est loin",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Den blindes pojk'",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Denise',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Denk ned noch',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '9be7f096-97ec-4615-8957-8d40b5dcbc41']},
#    {'song_title': 'Denk niet meer',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Der Mai ist vorbei',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['22317312-043c-4c60-bdd8-fd6f3baae6bc',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Des Sandlers Flucht',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Desolation Row',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Det sorgliga sändebudet',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Det ække meg, tjei',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Die Antwort weiß ganz allein der Wind',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dieu est à nos côtés',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dignity',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dirge',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dirt Road Blues',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dirty Lie',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dirty World',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['0bbbc496-c7b5-4b3f-bb6d-bd312827d6e5',
#      '372304d0-5e6a-4030-bc2b-09bdb0ee8abb',
#      '42a8f507-8412-4611-854f-926571049fa0',
#      '5ca3f318-d028-4151-ac73-78e2b2d6cdcc',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Disease of Conceit',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dit gaat over jou, babyboom',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Do Right to Me Baby (Do Unto Others)',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Doblen campanas',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Doing Alright',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dom ensligas allé',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Don't Let the Rain Come Down",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Don't Ya Tell Henry",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Don’t Ever Take Yourself Away',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Don’t Fall Apart on Me Tonight',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Don’t Fly Unless It’s Safe',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Don’t Let Anyone Write Your Story',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'bf6c29f5-b69f-4842-9031-37f9645d365d',
#      'd5709a02-30e0-4967-92ba-e584d8c21c72']},
#    {'song_title': 'Don’t Tell Him, Tell Me',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Don’t Think Twice, It’s All Right',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '9be7f096-97ec-4615-8957-8d40b5dcbc41']},
#    {'song_title': 'Dope Fiend Robber',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Down Along the Cove',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Down by the Station',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Down the Highway',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dr blind Willie McTell',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Dreamin' of You",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Drei Engel',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dress It Up, Better Have It All',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Drifter’s Escape',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Driftin' Too Far From Shore",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Du får hålla dej här',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Du skal ha flaks for å flire, du skal ha tur for å ta trikk',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Du Ängel, du',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Duquesne Whistle',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      'e9b419b5-ab8f-425c-8214-a7259e6efe10']},
#    {'song_title': 'Dusty Old Fairgrounds',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Dä Joker danz',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Där anar jag din hand',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'D’en haut de la tour du guet',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Early Roman Kings',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Earth Change',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['63533b2e-7bb8-4e7f-9c7d-68c4b05abeb4',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'East Laredo Blues',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'East Laredo Blues',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Edge of the Ocean',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': "Elle m'appartient (C'est une artiste)",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Emotionally Yours',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'End of the Line',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['0bbbc496-c7b5-4b3f-bb6d-bd312827d6e5',
#      '372304d0-5e6a-4030-bc2b-09bdb0ee8abb',
#      '42a8f507-8412-4611-854f-926571049fa0',
#      '5ca3f318-d028-4151-ac73-78e2b2d6cdcc',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Enough Is Enough',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Epitafium dla Dylana',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['654188a5-bbfc-41d8-aa27-86a946dfd757',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Er is leven na de dood',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Er komen andere tijden',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Eskimoen Quinn',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Eternal Circle',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Europaveien rundt',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Every Grain of Sand',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Every Grain of Sand',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['6ccbf2fe-c59d-46d8-8be4-756fdc9ff90c',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Every Time I Hear the Spirit',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '9be7f096-97ec-4615-8957-8d40b5dcbc41']},
#    {'song_title': 'Everybody Wants Somebody',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '96a1182f-e8e6-4df6-a811-82cb67d4565c']},
#    {'song_title': 'Everything Is Broken',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Falling Stones',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['5bca39a9-8999-49fb-a50f-fb9bfecc457c',
#      '72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'False Prophet',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Farewell',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8',
#      '9be7f096-97ec-4615-8957-8d40b5dcbc41']},
#    {'song_title': 'Farewell Pamilina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Farewell, Angelina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Farväl Angelina',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Father of Night',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Father of Night',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Field Mouse From Nebraska',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Final Theme (Pat Garrett and Bill the Kid)',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Firebird',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Firma Ziuty',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Flickan från landet i norr',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Floater (Too Much to Ask)',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Flykten',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Foot of Pride',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Forever Young',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['72c536dc-7137-4477-a521-567eeb840fa8']},
#    {'song_title': 'Forever Young',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['49af6b4f-faa0-4689-aa46-5493a329ecd7',
#      '72c536dc-7137-4477-a521-567eeb840fa8',
#      '981e9e3e-f683-4923-a7fa-cf56ada171d9',
#      'a35237a0-4f47-40a6-b6f3-1e786db23402']},
#    {'song_title': 'Forever young',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': 

#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['257b03c5-85b7-4ce9-84b4-6e24aa888205',
#      '6656d352-e611-4474-b1a3-5a936d8a1910',
#      'e4378b7a-6138-441a-aa34-50e11a562066']},
#    {'song_title': 'You’d Like That Wouldn’t You',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['03180405-1b26-42dc-80da-7e50fbb4c936',
#      '257b03c5-85b7-4ce9-84b4-6e24aa888205',
#      '91e4a2f7-b787-4076-889a-301bbda35a26',
#      'c81c430f-dbe1-4a1e-954f-2a89114331e9',
#      'e4378b7a-6138-441a-aa34-50e11a562066',
#      'ff4fc9b6-bdcd-44ee-b053-c1ccbe47fe4b']}]},
#  {'artist_mbid': '8ab64ebd-200e-47af-a3fc-92540e186214',
#   'works': [{'song_title': 'At the Beach, in Every Life',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['8ab64ebd-200e-47af-a3fc-92540e186214']},
#    {'song_title': 'Balsam Fir',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['8ab64ebd-200e-47af-a3fc-92540e186214',
#      'd209dc86-3766-4f59-a12c-6bbdc813fb4e']},
#    {'song_title': 'Chemistry',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['8ab64ebd-200e-47af-a3fc-92540e186214',
#      'ce2e9bb8-edcd-49c6-9607-9c74df4790dd']},
#    {'song_title': 'Sailor Song',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['8ab64ebd-200e-47af-a3fc-92540e186214']}]},
#  {'artist_mbid': '89e95aa3-bd49-4af3-9c87-0d88b2093bb0',
#   'works': [{'song_title': 'pink horizon',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['89e95aa3-bd49-4af3-9c87-0d88b2093bb0']}]},
#  {'artist_mbid': 'd8e07579-ff5a-41f2-b7a7-c71880b8287a',
#   'works': [{'song_title': 'Remember Me',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['1d8876d9-d335-4432-92af-e396de19a943',
#      '5d813cec-4901-4779-b07c-afa16b284e0d',
#      '6517f936-ec0a-429b-a944-2694bb56f688',
#      'c5c19deb-fce6-4664-b2d1-ca6fc490590a',
#      'cde68d38-95df-42c2-bfb9-d9693ce862f0',
#      'd8e07579-ff5a-41f2-b7a7-c71880b8287a']},
#    {'song_title': 'Remember Me (Intro)',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['5d813cec-4901-4779-b07c-afa16b284e0d',
#      'c5c19deb-fce6-4664-b2d1-ca6fc490590a',
#      'd8e07579-ff5a-41f2-b7a7-c71880b8287a']}]},
#  {'artist_mbid': 'd25f6294-686a-4569-b1b9-fe64bfef2519',
#   'works': [{'song_title': 'All the Way',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['2257da02-e5b8-4da0-bff5-1db1673483d1',
#      '2588180b-9819-46b3-93c9-0fa89dd199b5',
#      '30e036b2-8674-472d-82bf-2b869ad28d99',
#      '4ced4eb2-ed74-4ca1-9d32-eb709b5f348f',
#      'abaa2544-8476-401c-ad32-042b6bfac116',
#      'd25f6294-686a-4569-b1b9-fe64bfef2519']},
#    {'song_title': "Drink Don't Need No Mix",
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['0b427dad-1ee5-48f1-aa4b-026680a3338e',
#      '9e885dfe-5cd3-454f-99fc-d28847de6ce2',
#      'c563a7dd-4bda-4fa1-840f-0f882849fbc4',
#      'd25f6294-686a-4569-b1b9-fe64bfef2519',
#      'fce14ef9-e1df-4821-a4cd-e2ef9045460e']},
#    {'song_title': 'PISTOL PACCIN',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['2873b450-13c6-4ca1-8ca3-646c25af3202',
#      '4ac35d1d-3755-4733-b6f2-772514d67a6e',
#      '8b8985eb-f71f-4229-9f11-171a7aac98c1',
#      'bbbe3da3-0563-429f-8394-5c546cc8b9bc',
#      'c45d161f-83ce-4464-ba41-44202e6916d9',
#      'd0417cd9-dc5c-48e2-9a1b-5a5a51c804cd',
#      'd25f6294-686a-4569-b1b9-fe64bfef2519',
#      'e70235d5-f15f-4750-b916-42aadcd579a7']}]},
#  {'artist_mbid': '35214d53-009b-45d9-8a00-6664325b9e2a',
#   'works': [{'song_title': 'uncomfy',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['155cfd40-dcde-471e-acc0-32179916165c',
#      '35214d53-009b-45d9-8a00-6664325b9e2a',
#      '5c6394b5-3af5-43f2-83c0-a061750ad233',
#      '7d7fde25-6f14-497b-8326-770a6dbfc2d8']}]},
#  {'artist_mbid': '91faf71d-89f3-4bd6-8a54-3701a0dd753f',
#   'works': [{'song_title': 'spreading love',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['91faf71d-89f3-4bd6-8a54-3701a0dd753f']}]},
#  {'artist_mbid': '502cf908-9921-48bc-bf0e-265c881c0156',
#   'works': [{'song_title': '12 to 12',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'alibi',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'back to friends',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'burner phone',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'canal street',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'caroline',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'come closer',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'crushing',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'dime',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'do i ever cross your mind',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156',
#      '736c4c01-029f-42d2-8a1e-ff87f65073fa']},
#    {'song_title': 'don’t let me down',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'fine',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'i wish i knew how to quit you',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'in your arms',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'ivy',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'i’ll remember tonight',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['47ec3ea7-cb72-4ebf-a269-8de3bad1400f',
#      '502cf908-9921-48bc-bf0e-265c881c0156',
#      'b18bf613-ed9d-401c-b2c2-2716bf95291a']},
#    {'song_title': 'makes me want you',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'my house is warm',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'never find u',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'nothing left to say',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'perfume',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'savior',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'silhouette',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'through it all',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'under the mat',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'undressed',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'undressed',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'we never dated',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'weak',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'why are we like this',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'willow',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']},
#    {'song_title': 'would’ve been you',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156',
#      '736c4c01-029f-42d2-8a1e-ff87f65073fa']},
#    {'song_title': 'you’re so pretty',
#     'release_date_year': None,
#     'release_month': None,
#     'contributor_mbids': ['502cf908-9921-48bc-bf0e-265c881c0156']}]}]

# %%
# %env PIP_CERT=/etc/ssl/certs/ca-certificates.crt
# %env REQUESTS_CA_BUNDLE=/etc/ssl/certs/ca-certificates.crt
# %env SSL_CERT_FILE=/etc/ssl/certs/ca-certificates.crt
# Out:
# env: PIP_CERT=/etc/ssl/certs/ca-certificates.crt
# env: REQUESTS_CA_BUNDLE=/etc/ssl/certs/ca-certificates.crt
# env: SSL_CERT_FILE=/etc/ssl/certs/ca-certificates.crt

# %%
import apis.wikidata as wd

# %%
wd.get_artist_family_musicians(data[45]['artist_mbid'])
# Out:
# [{'relation_property': 'P40',
#   'relation': 'child',
#   'qid': 'Q311238',
#   'label': 'Sean Lennon',
#   'description': 'American composer and musician, son of John Lennon and Yoko Ono',
#   'occupations': [],
#   'has_mbid': True,
#   'relative_mbid': '722c6718-0c61-4db2-a8bc-993a8c5d2baf'},
#  {'relation_property': 'P26',
#   'relation': 'spouse',
#   'qid': 'Q117012',
#   'label': 'Yoko Ono',
#   'description': 'Japanese artist and activist based in the United States (born 1933)',
#   'occupations': [],
#   'has_mbid': True,
#   'relative_mbid': 'b0b33754-a664-43b7-ba00-be0dc4ec2396'},
#  {'relation_property': 'P40',
#   'relation': 'child',
#   'qid': 'Q357974',
#   'label': 'Julian Lennon',
#   'description': 'English musician; son of John Lennon',
#   'occupations': [],
#   'has_mbid': True,
#   'relative_mbid': 'fbe1a6d6-12c9-459e-bf73-fdcc76b14b7e'},
#  {'relation_property': 'P3373',
#   'relation': 'sibling',
#   'qid': 'Q3189024',
#   'label': 'Julia Baird',
#   'description': 'British writer (born 1947)',
#   'occupations': [],
#   'has_mbid': False,
#   'relative_mbid': None},
#  {'relation_property': 'P22',
#   'relation': 'father',
#   'qid': 'Q3646297',
#   'label': 'Alfred Lennon',
#   'description': 'father of English musician John Lennon (1912–1976)',
#   'occupations': [],
#   'has_mbid': True,
#   'relative_mbid': '2b3fbe10-7cf3-4f32-88d1-fbe54dec4649'}]
